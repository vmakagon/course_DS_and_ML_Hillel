# %%
import argparse
import torch
import torch.nn.functional as F
import torch.optim as optim
import datetime
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torchvision import datasets, transforms

from torchsummary import summary

# %%
from google.colab import drive
drive.mount('/content/drive')

current_path = '/content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import sys, os
import pandas as pd
import numpy as np

def writeToJSONFile(path, fileName, data):
    print(path)
    print(fileName)
    filePathNameWExt = path + fileName + '.json'
    print(filePathNameWExt)
    with open(filePathNameWExt, 'w') as fp:
        json.dump(data, fp)
    return path + fileName

def readFromJSONFile(path, fileName):
    filePathNameWExt = path + '/' + fileName + '.json'
    with open(filePathNameWExt, 'r') as fp:
        data = json.load(fp)
    return data

def save_my_param(model, dict_for_save, after_n_epochs=0, previous_file=None):
    # путь к файлу нужно указывать самостоятельно без расширения
    # after_n_epochs    - накапливаем количество эпох и в новый файл дописываем

    if previous_file :
        file_dir = os.path.dirname(previous_file)
        file_name_full = os.path.basename(previous_file)
        file_name = os.path.splitext(file_name_full)[0] + '_' + str(after_n_epochs)
    else:
#         это два глобальныйх (входящих) значения (пока пусть так работает)
        file_dir = current_path
        file_name = str(model.name2) + '_param_'+str(after_n_epochs).rjust(2,'0')
    d = dict(dict_for_save=dict_for_save,after_n_epochs=after_n_epochs)
    d_pd = pd.DataFrame([d])
    return writeToJSONFile(file_dir,file_name,d_pd.to_json(orient='split'))

# %%
class CNN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.name2 = 'CNN'
        
        self.conv1 = torch.nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=0, stride=1)
        self.ac1   = torch.nn.ReLU()
        self.conv2 = torch.nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=0, stride=1)
#         maxpool
        self.ac2   = torch.nn.ReLU()
        self.conv3 = torch.nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1, stride=1)
#         maxpool        
        self.ac3   = torch.nn.ReLU()
#         flatten
        self.fc4 = torch.nn.Linear(3136, 256)
        self.ac4 = torch.nn.ReLU()
        self.fc5 = torch.nn.Linear(256,  128)
        self.ac5 = torch.nn.ReLU()
        self.fc6 = torch.nn.Linear( 128,   10)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.ac1(x)
        x = self.conv2(x)
        x = F.max_pool2d(x, kernel_size=2, stride=2)
        x = self.ac2(x)
        x = self.conv3(x)
        x = F.max_pool2d(x, kernel_size=2, stride=2)
        x = self.ac3(x)
        x = x.view(-1, 64*7*7)
        x = self.fc4(x)
        x = self.ac4(x)
        x = self.fc5(x)
        x = self.ac5(x)
        x = self.fc6(x)
        return F.log_softmax(x, dim=1)

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
      
#         data = data.reshape(len(data), 3072)
      
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} correct: {:.2f}% '.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), 100. * correct/len(train_loader.dataset)))
    return loss.item(), correct / len(train_loader.dataset)
  
def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
          
#             data = data.reshape(len(data),3072)
          
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)
      
def read_settings():
    # Training settings
    parser = argparse.ArgumentParser(description='PyTorch Examples')
    parser.add_argument('--batch-size', type=int, default=64, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=15, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=80, metavar='N',
                        help='how many batches to wait before logging training status')

    parser.add_argument('--save-model', action='store_true', default=True,
                        help='For Saving the current Model')
    
    args = parser.parse_args([])
    use_cuda = not args.no_cuda and torch.cuda.is_available()
    print('use_cuda : {}'.format(use_cuda))
    
    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")

    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
    return args, kwargs, device

def load_dataset(args,kwargs):
    # CIFAR10.
    train_dataset = datasets.CIFAR10('data', 
                                      train=True, 
                                      download=True, 
                                      transform=transforms.ToTensor())

    test_dataset = datasets.CIFAR10('data', 
                                     train=False, 
                                     transform=transforms.ToTensor())
    print(len(train_dataset),len(test_dataset),type(test_dataset))
    
    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=args.batch_size, 
                                               shuffle=True, 
                                               **kwargs)
    test_loader = torch.utils.data.DataLoader(test_dataset,
                                              batch_size=args.test_batch_size,
                                              shuffle=True, 
                                              **kwargs)
    print(train_loader.dataset.data.shape)
    print(test_loader.dataset.data.shape)
    
    classes = ['plane', 'car', 'bird', 'cat', 'deer', 
               'dog', 'frog', 'horse', 'ship', 'truck']
    
    for data, target in train_loader:
        break
    print(data.shape)
    print(data[0].shape)
    plt.figure(figsize=(12,5))
    for i in range(10):
        plt.subplot(2, 5, i+1)
        plt.axis('off')
        plt.title(classes[target[i]])
        plt.imshow(data[i].permute(1, 2, 0))
    plt.show()
    return train_loader, test_loader

def show_2_in_line(loss_train, accuracy_train, loss_test, accuracy_test, epochs=1, model_name=''):
    plt.figure(figsize=(12,4))
    plt.subplot(1, 2, 1)
    plt.title(model_name + ' - Loss')
    plt.xlabel('epochs')
    plt.plot(range(epochs),loss_train, 'g',label='train')
    plt.plot(range(epochs),loss_test, 'r',label='test')
    plt.legend()
    plt.grid()
    plt.subplot(1, 2, 2)
    plt.title(model_name + ' - Accuracy')
    plt.xlabel('epochs')
    plt.plot(range(epochs),accuracy_train,'g',label='train')
    plt.plot(range(epochs),accuracy_test,'r',label='test')
    plt.legend()
    plt.grid()
    plt.show()
  
def main():

    args, kwargs, device = read_settings()
    train_loader, test_loader = load_dataset(args, kwargs)
    
# start - загрузка модели + параметры накопления

    model = CNN().to(device)
    print(str(model.name2))
    summary(model, input_size=(3,32,32))
  
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)


    train_last_loss_list = []
    train_accuracy_list = []
    test_average_loss_list = []
    test_accuracy_list = []
    
    start_epoch = 1
    
    dict_for_save = dict()
# end - загрузка модели + параметры накопления
    start = datetime.datetime.now()
    for epoch in range(start_epoch, args.epochs + 1):
        train_last_loss, train_accuracy = train(args, model, device, train_loader, optimizer, epoch)
        test_average_loss, test_accuracy = test(args, model, device, test_loader)
        train_last_loss_list.append(train_last_loss)
        train_accuracy_list.append(train_accuracy)
        test_average_loss_list.append(test_average_loss)
        test_accuracy_list.append(test_accuracy)

#         start - что сохраняем каждую эпоху по одной модели
        if (args.save_model):
            f = current_path + str(model.name2) + '_model_' + str(epoch).rjust(2,'0') + ".pt"
            torch.save(model,f)
            print('Save model in {}'.format(f))
        dict_for_save = dict(train_last_loss_list = train_last_loss_list,
                             train_train_accuracy_listaccuracy = train_accuracy_list,
                             test_average_loss_list = test_average_loss_list,
                             test_accuracy_list = test_accuracy_list
#                             ,может время или что еще захочу
                            )
        print(save_my_param(model, dict_for_save, after_n_epochs=epoch))
#         end - что сохраняем каждую эпоху по одной модели

    end = datetime.datetime.now()
    time_train = end-start        
    print('Model ( {} ) time - {}'.format(str(model.name2), time_train))
    
    show_2_in_line(train_last_loss_list, train_accuracy_list, test_average_loss_list, test_accuracy_list, args.epochs, str(model.name2))

# %%
main()
# Out:
# use_cuda : False
# Files already downloaded and verified
# 50000 10000 <class 'torchvision.datasets.cifar.CIFAR10'>
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# torch.Size([64, 3, 32, 32])
# torch.Size([3, 32, 32])
# CNN
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 30, 30]             448
#               ReLU-2           [-1, 16, 30, 30]               0
#             Conv2d-3           [-1, 32, 28, 28]           4,640
#               ReLU-4           [-1, 32, 14, 14]               0
#             Conv2d-5           [-1, 64, 14, 14]          18,496
#               ReLU-6             [-1, 64, 7, 7]               0
#             Linear-7                  [-1, 256]         803,072
#               ReLU-8                  [-1, 256]               0
#             Linear-9                  [-1, 128]          32,896
#              ReLU-10                  [-1, 128]               0
#            Linear-11                   [-1, 10]           1,290
# ================================================================
# Total params: 860,842
# Trainable params: 860,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.58
# Params size (MB): 3.28
# Estimated Total Size (MB): 3.88
# ----------------------------------------------------------------
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.289847 correct: 0.02%
# Train Epoch: 1 [5120/50000 (10%)]	Loss: 2.299096 correct: 1.11%
# Train Epoch: 1 [10240/50000 (20%)]	Loss: 2.301849 correct: 2.21%
# Train Epoch: 1 [15360/50000 (31%)]	Loss: 2.296650 correct: 3.28%
# Train Epoch: 1 [20480/50000 (41%)]	Loss: 2.304394 correct: 4.44%
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 2.299462 correct: 5.64%
# Train Epoch: 1 [30720/50000 (61%)]	Loss: 2.301069 correct: 6.84%
# Train Epoch: 1 [35840/50000 (72%)]	Loss: 2.303143 correct: 7.99%
# Train Epoch: 1 [40960/50000 (82%)]	Loss: 2.301881 correct: 9.27%
# Train Epoch: 1 [46080/50000 (92%)]	Loss: 2.298037 correct: 10.93%
#
# Test set: Average loss: 2.2982, Accuracy: 1528/10000 (15.28%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_01.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_01
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_01.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_01
# Train Epoch: 2 [0/50000 (0%)]	Loss: 2.298727 correct: 0.02%
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Train Epoch: 2 [5120/50000 (10%)]	Loss: 2.298175 correct: 1.82%
# Train Epoch: 2 [10240/50000 (20%)]	Loss: 2.293721 correct: 3.56%
# Train Epoch: 2 [15360/50000 (31%)]	Loss: 2.280982 correct: 5.31%
# Train Epoch: 2 [20480/50000 (41%)]	Loss: 2.277111 correct: 6.98%
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 2.248677 correct: 8.88%
# Train Epoch: 2 [30720/50000 (61%)]	Loss: 2.156120 correct: 10.72%
# Train Epoch: 2 [35840/50000 (72%)]	Loss: 2.104603 correct: 12.85%
# Train Epoch: 2 [40960/50000 (82%)]	Loss: 2.011859 correct: 15.27%
# Train Epoch: 2 [46080/50000 (92%)]	Loss: 1.966611 correct: 17.91%
#
# Test set: Average loss: 2.1170, Accuracy: 2476/10000 (24.76%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_02.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_02
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_02.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_02
# Train Epoch: 3 [0/50000 (0%)]	Loss: 2.165605 correct: 0.03%
# Train Epoch: 3 [5120/50000 (10%)]	Loss: 1.944724 correct: 2.86%
# Train Epoch: 3 [10240/50000 (20%)]	Loss: 2.050647 correct: 5.83%
# Train Epoch: 3 [15360/50000 (31%)]	Loss: 1.853469 correct: 9.08%
# Train Epoch: 3 [20480/50000 (41%)]	Loss: 1.934204 correct: 12.29%
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.888907 correct: 15.61%
# Train Epoch: 3 [30720/50000 (61%)]	Loss: 1.839401 correct: 18.93%
# Train Epoch: 3 [35840/50000 (72%)]	Loss: 1.930685 correct: 22.44%
# Train Epoch: 3 [40960/50000 (82%)]	Loss: 1.776544 correct: 26.00%
# Train Epoch: 3 [46080/50000 (92%)]	Loss: 1.695908 correct: 29.79%
#
# Test set: Average loss: 1.7416, Accuracy: 3751/10000 (37.51%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_03.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_03
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_03.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_03
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.785697 correct: 0.03%
# Train Epoch: 4 [5120/50000 (10%)]	Loss: 1.849515 correct: 3.98%
# Train Epoch: 4 [10240/50000 (20%)]	Loss: 1.791820 correct: 7.97%
# Train Epoch: 4 [15360/50000 (31%)]	Loss: 1.650597 correct: 12.10%
# Train Epoch: 4 [20480/50000 (41%)]	Loss: 1.593922 correct: 16.23%
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.524358 correct: 20.42%
# Train Epoch: 4 [30720/50000 (61%)]	Loss: 1.342937 correct: 24.68%
# Train Epoch: 4 [35840/50000 (72%)]	Loss: 1.478141 correct: 29.16%
# Train Epoch: 4 [40960/50000 (82%)]	Loss: 1.430695 correct: 33.59%
# Train Epoch: 4 [46080/50000 (92%)]	Loss: 1.913327 correct: 38.10%
#
# Test set: Average loss: 1.6155, Accuracy: 4066/10000 (40.66%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_04.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_04
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_04.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_04
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.725704 correct: 0.05%
# Train Epoch: 5 [5120/50000 (10%)]	Loss: 1.473189 correct: 4.72%
# Train Epoch: 5 [10240/50000 (20%)]	Loss: 1.264471 correct: 9.44%
# Train Epoch: 5 [15360/50000 (31%)]	Loss: 1.269292 correct: 14.23%
# Train Epoch: 5 [20480/50000 (41%)]	Loss: 1.411228 correct: 18.94%
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.354476 correct: 23.71%
# Train Epoch: 5 [30720/50000 (61%)]	Loss: 1.205726 correct: 28.59%
# Train Epoch: 5 [35840/50000 (72%)]	Loss: 1.331424 correct: 33.48%
# Train Epoch: 5 [40960/50000 (82%)]	Loss: 1.471110 correct: 38.34%
# Train Epoch: 5 [46080/50000 (92%)]	Loss: 1.308203 correct: 43.32%
#
# Test set: Average loss: 1.5851, Accuracy: 4478/10000 (44.78%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_05.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_05
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_05.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_05
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.508738 correct: 0.05%
# Train Epoch: 6 [5120/50000 (10%)]	Loss: 1.540121 correct: 5.12%
# Train Epoch: 6 [10240/50000 (20%)]	Loss: 1.421115 correct: 10.23%
# Train Epoch: 6 [15360/50000 (31%)]	Loss: 1.412310 correct: 15.37%
# Train Epoch: 6 [20480/50000 (41%)]	Loss: 1.290474 correct: 20.52%
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.241356 correct: 25.69%
# Train Epoch: 6 [30720/50000 (61%)]	Loss: 1.386490 correct: 30.79%
# Train Epoch: 6 [35840/50000 (72%)]	Loss: 1.297553 correct: 35.98%
# Train Epoch: 6 [40960/50000 (82%)]	Loss: 1.442012 correct: 41.12%
# Train Epoch: 6 [46080/50000 (92%)]	Loss: 1.541365 correct: 46.54%
#
# Test set: Average loss: 1.3665, Accuracy: 5070/10000 (50.70%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_06.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_06
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_06.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_06
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.439055 correct: 0.05%
# Train Epoch: 7 [5120/50000 (10%)]	Loss: 1.361150 correct: 5.51%
# Train Epoch: 7 [10240/50000 (20%)]	Loss: 1.394800 correct: 10.98%
# Train Epoch: 7 [15360/50000 (31%)]	Loss: 1.147065 correct: 16.28%
# Train Epoch: 7 [20480/50000 (41%)]	Loss: 1.251103 correct: 21.77%
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.303974 correct: 27.22%
# Train Epoch: 7 [30720/50000 (61%)]	Loss: 1.236901 correct: 32.69%
# Train Epoch: 7 [35840/50000 (72%)]	Loss: 1.425878 correct: 38.14%
# Train Epoch: 7 [40960/50000 (82%)]	Loss: 1.385972 correct: 43.65%
# Train Epoch: 7 [46080/50000 (92%)]	Loss: 1.329377 correct: 49.29%
#
# Test set: Average loss: 1.2791, Accuracy: 5443/10000 (54.43%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_07.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_07
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_07.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_07
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.226870 correct: 0.07%
# Train Epoch: 8 [5120/50000 (10%)]	Loss: 1.525144 correct: 5.66%
# Train Epoch: 8 [10240/50000 (20%)]	Loss: 1.146594 correct: 11.22%
# Train Epoch: 8 [15360/50000 (31%)]	Loss: 1.339475 correct: 17.01%
# Train Epoch: 8 [20480/50000 (41%)]	Loss: 1.215411 correct: 22.63%
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.102516 correct: 28.37%
# Train Epoch: 8 [30720/50000 (61%)]	Loss: 1.398374 correct: 34.23%
# Train Epoch: 8 [35840/50000 (72%)]	Loss: 1.124121 correct: 39.91%
# Train Epoch: 8 [40960/50000 (82%)]	Loss: 1.253128 correct: 45.74%
# Train Epoch: 8 [46080/50000 (92%)]	Loss: 1.446430 correct: 51.46%
#
# Test set: Average loss: 1.3014, Accuracy: 5332/10000 (53.32%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_08.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_08
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_08.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_08
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.212540 correct: 0.08%
# Train Epoch: 9 [5120/50000 (10%)]	Loss: 1.259679 correct: 6.00%
# Train Epoch: 9 [10240/50000 (20%)]	Loss: 1.158890 correct: 11.98%
# Train Epoch: 9 [15360/50000 (31%)]	Loss: 1.150446 correct: 17.86%
# Train Epoch: 9 [20480/50000 (41%)]	Loss: 1.212924 correct: 23.91%
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.201784 correct: 29.82%
# Train Epoch: 9 [30720/50000 (61%)]	Loss: 1.148693 correct: 35.85%
# Train Epoch: 9 [35840/50000 (72%)]	Loss: 1.048638 correct: 41.77%
# Train Epoch: 9 [40960/50000 (82%)]	Loss: 1.245016 correct: 47.75%
# Train Epoch: 9 [46080/50000 (92%)]	Loss: 1.018692 correct: 53.86%
#
# Test set: Average loss: 1.2059, Accuracy: 5709/10000 (57.09%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_09.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_09
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_09.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_09
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.239142 correct: 0.07%
# Train Epoch: 10 [5120/50000 (10%)]	Loss: 1.261134 correct: 6.35%
# Train Epoch: 10 [10240/50000 (20%)]	Loss: 1.325531 correct: 12.54%
# Train Epoch: 10 [15360/50000 (31%)]	Loss: 1.330005 correct: 18.81%
# Train Epoch: 10 [20480/50000 (41%)]	Loss: 1.090735 correct: 25.05%
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.026675 correct: 31.26%
# Train Epoch: 10 [30720/50000 (61%)]	Loss: 1.149449 correct: 37.55%
# Train Epoch: 10 [35840/50000 (72%)]	Loss: 0.912131 correct: 43.86%
# Train Epoch: 10 [40960/50000 (82%)]	Loss: 0.775433 correct: 50.07%
# Train Epoch: 10 [46080/50000 (92%)]	Loss: 1.258724 correct: 56.39%
#
# Test set: Average loss: 1.1619, Accuracy: 5920/10000 (59.20%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_10.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_10
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_10.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_10
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.941957 correct: 0.08%
# Train Epoch: 11 [5120/50000 (10%)]	Loss: 1.102270 correct: 6.51%
# Train Epoch: 11 [10240/50000 (20%)]	Loss: 1.239974 correct: 12.92%
# Train Epoch: 11 [15360/50000 (31%)]	Loss: 0.930069 correct: 19.35%
# Train Epoch: 11 [20480/50000 (41%)]	Loss: 1.034648 correct: 25.96%
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.863990 correct: 32.40%
# Train Epoch: 11 [30720/50000 (61%)]	Loss: 1.126572 correct: 38.98%
# Train Epoch: 11 [35840/50000 (72%)]	Loss: 1.175594 correct: 45.57%
# Train Epoch: 11 [40960/50000 (82%)]	Loss: 1.060392 correct: 52.07%
# Train Epoch: 11 [46080/50000 (92%)]	Loss: 0.885656 correct: 58.62%
#
# Test set: Average loss: 1.1169, Accuracy: 6068/10000 (60.68%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_11.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_11
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_11.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_11
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.892086 correct: 0.09%
# Train Epoch: 12 [5120/50000 (10%)]	Loss: 1.157345 correct: 6.88%
# Train Epoch: 12 [10240/50000 (20%)]	Loss: 0.841070 correct: 13.60%
# Train Epoch: 12 [15360/50000 (31%)]	Loss: 0.971304 correct: 20.34%
# Train Epoch: 12 [20480/50000 (41%)]	Loss: 1.063542 correct: 27.09%
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 1.169050 correct: 33.95%
# Train Epoch: 12 [30720/50000 (61%)]	Loss: 0.858711 correct: 40.81%
# Train Epoch: 12 [35840/50000 (72%)]	Loss: 1.024038 correct: 47.64%
# Train Epoch: 12 [40960/50000 (82%)]	Loss: 0.952775 correct: 54.49%
# Train Epoch: 12 [46080/50000 (92%)]	Loss: 0.844064 correct: 61.21%
#
# Test set: Average loss: 1.1485, Accuracy: 5994/10000 (59.94%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_12.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_12
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_12.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_12
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.256871 correct: 0.07%
# Train Epoch: 13 [5120/50000 (10%)]	Loss: 1.060228 correct: 7.15%
# Train Epoch: 13 [10240/50000 (20%)]	Loss: 0.947792 correct: 14.14%
# Train Epoch: 13 [15360/50000 (31%)]	Loss: 0.727868 correct: 21.25%
# Train Epoch: 13 [20480/50000 (41%)]	Loss: 0.921821 correct: 28.31%
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.728265 correct: 35.46%
# Train Epoch: 13 [30720/50000 (61%)]	Loss: 0.916535 correct: 42.46%
# Train Epoch: 13 [35840/50000 (72%)]	Loss: 0.816472 correct: 49.46%
# Train Epoch: 13 [40960/50000 (82%)]	Loss: 0.743059 correct: 56.68%
# Train Epoch: 13 [46080/50000 (92%)]	Loss: 0.822877 correct: 63.62%
#
# Test set: Average loss: 1.0761, Accuracy: 6278/10000 (62.78%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_13.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_13
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_13.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_13
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.855001 correct: 0.09%
# Train Epoch: 14 [5120/50000 (10%)]	Loss: 1.131317 correct: 7.43%
# Train Epoch: 14 [10240/50000 (20%)]	Loss: 0.885214 correct: 14.83%
# Train Epoch: 14 [15360/50000 (31%)]	Loss: 0.840324 correct: 22.17%
# Train Epoch: 14 [20480/50000 (41%)]	Loss: 0.753662 correct: 29.45%
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.671439 correct: 36.81%
# Train Epoch: 14 [30720/50000 (61%)]	Loss: 0.807285 correct: 44.12%
# Train Epoch: 14 [35840/50000 (72%)]	Loss: 0.776407 correct: 51.36%
# Train Epoch: 14 [40960/50000 (82%)]	Loss: 0.660799 correct: 58.61%
# Train Epoch: 14 [46080/50000 (92%)]	Loss: 0.684425 correct: 65.96%
#
# Test set: Average loss: 1.0401, Accuracy: 6453/10000 (64.53%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_14.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_14
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_14.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_14
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.709769 correct: 0.09%
# Train Epoch: 15 [5120/50000 (10%)]	Loss: 0.773624 correct: 7.73%
# Train Epoch: 15 [10240/50000 (20%)]	Loss: 0.570975 correct: 15.32%
# Train Epoch: 15 [15360/50000 (31%)]	Loss: 0.700920 correct: 22.89%
# Train Epoch: 15 [20480/50000 (41%)]	Loss: 0.701647 correct: 30.53%
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.663962 correct: 38.02%
# Train Epoch: 15 [30720/50000 (61%)]	Loss: 0.793343 correct: 45.51%
# Train Epoch: 15 [35840/50000 (72%)]	Loss: 0.712397 correct: 53.00%
# Train Epoch: 15 [40960/50000 (82%)]	Loss: 0.771327 correct: 60.68%
# Train Epoch: 15 [46080/50000 (92%)]	Loss: 0.446008 correct: 68.30%
#
# Test set: Average loss: 1.0959, Accuracy: 6325/10000 (63.25%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_model_15.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# CNN_param_15
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_15.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/CNN_param_15
# Model ( CNN ) time - 0:31:01.705005
