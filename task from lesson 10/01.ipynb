# %%
import argparse
import torch
import torch.nn.functional as F
import torch.optim as optim
import datetime
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torchvision import datasets, transforms

from torchsummary import summary

# %%
from google.colab import drive
drive.mount('/content/drive')

current_path = '/content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import sys, os
import pandas as pd
import numpy as np

def writeToJSONFile(path, fileName, data):
    print(path)
    print(fileName)
    filePathNameWExt = path + fileName + '.json'
    print(filePathNameWExt)
    with open(filePathNameWExt, 'w') as fp:
        json.dump(data, fp)
    return path + fileName

def readFromJSONFile(path, fileName):
    filePathNameWExt = path + '/' + fileName + '.json'
    with open(filePathNameWExt, 'r') as fp:
        data = json.load(fp)
    return data

def save_my_param(model, dict_for_save, after_n_epochs=0, previous_file=None):
    # путь к файлу нужно указывать самостоятельно без расширения
    # after_n_epochs    - накапливаем количество эпох и в новый файл дописываем

    if previous_file :
        file_dir = os.path.dirname(previous_file)
        file_name_full = os.path.basename(previous_file)
        file_name = os.path.splitext(file_name_full)[0] + '_' + str(after_n_epochs)
    else:
#         это два глобальныйх (входящих) значения (пока пусть так работает)
        file_dir = current_path
        file_name = str(model.name2) + '_param_'+str(after_n_epochs).rjust(2,'0')
    d = dict(dict_for_save=dict_for_save,after_n_epochs=after_n_epochs)
    d_pd = pd.DataFrame([d])
    return writeToJSONFile(file_dir,file_name,d_pd.to_json(orient='split'))
    
def load_weight(load_file):
    file_dir = os.path.dirname(load_file)
    file_name_full = os.path.basename(load_file)
    file_name = os.path.splitext(file_name_full)[0]

    f = readFromJSONFile(file_dir, file_name)
    pd_p = pd.read_json(f, orient = 'split')

    w  = torch.tensor(pd_p['w'][0], requires_grad=True)
    b  = torch.tensor(pd_p['b'][0], requires_grad=True)
    w2 = torch.tensor(pd_p['w2'][0], requires_grad=True)
    b2 = torch.tensor(pd_p['b2'][0], requires_grad=True)
    w3 = torch.tensor(pd_p['w3'][0], requires_grad=True)
    b3 = torch.tensor(pd_p['b3'][0], requires_grad=True) 
    return w, b, w2, b2, w3, b3

# %%
# пока только содним классом моделей работаю

class FullyConnectedNN(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.name2 = 'FullyConnectedNN'
        self.fc1 = torch.nn.Linear(3072, 1024)
        self.ac1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(1024,  256)
        self.ac2 = torch.nn.ReLU()
        self.fc3 = torch.nn.Linear( 256,  128)
        self.ac3 = torch.nn.ReLU()
        self.fc4 = torch.nn.Linear( 128,   10)
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.ac1(x)
        x = self.fc2(x)
        x = self.ac2(x)
        x = self.fc3(x)
        x = self.ac3(x)
        x = self.fc4(x)
        return F.log_softmax(x, dim=1)

# %%
def train(args, model, device, train_loader, optimizer, epoch):
    model.train()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
      
        data = data.reshape(len(data), 3072)
      
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        loss.backward()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} correct: {:.2f}% '.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(), 100. * correct/len(train_loader.dataset)))
    return loss.item(), correct / len(train_loader.dataset)
  
def test(args, model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
          
            data = data.reshape(len(data),3072)
          
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)
      
def read_settings():
    # Training settings
    parser = argparse.ArgumentParser(description='PyTorch Examples')
    parser.add_argument('--batch-size', type=int, default=64, metavar='N',
                        help='input batch size for training (default: 64)')
    parser.add_argument('--test-batch-size', type=int, default=1000, metavar='N',
                        help='input batch size for testing (default: 1000)')
    parser.add_argument('--epochs', type=int, default=25, metavar='N',
                        help='number of epochs to train (default: 10)')
    parser.add_argument('--lr', type=float, default=0.01, metavar='LR',
                        help='learning rate (default: 0.01)')
    parser.add_argument('--momentum', type=float, default=0.5, metavar='M',
                        help='SGD momentum (default: 0.5)')
    parser.add_argument('--no-cuda', action='store_true', default=False,
                        help='disables CUDA training')
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('--log-interval', type=int, default=80, metavar='N',
                        help='how many batches to wait before logging training status')

    parser.add_argument('--save-model', action='store_true', default=True,
                        help='For Saving the current Model')
    
    args = parser.parse_args([])
    use_cuda = not args.no_cuda and torch.cuda.is_available()
    print('use_cuda : {}'.format(use_cuda))
    
    torch.manual_seed(args.seed)

    device = torch.device("cuda" if use_cuda else "cpu")

    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
    return args, kwargs, device

def load_dataset(args,kwargs):
    # CIFAR10.
    train_dataset = datasets.CIFAR10('data', 
                                      train=True, 
                                      download=True, 
                                      transform=transforms.ToTensor())

    test_dataset = datasets.CIFAR10('data', 
                                     train=False, 
                                     transform=transforms.ToTensor())
    print(len(train_dataset),len(test_dataset),type(test_dataset))
    
    train_loader = torch.utils.data.DataLoader(train_dataset,
                                               batch_size=args.batch_size, 
                                               shuffle=True, 
                                               **kwargs)
    test_loader = torch.utils.data.DataLoader(test_dataset,
                                              batch_size=args.test_batch_size,
                                              shuffle=True, 
                                              **kwargs)
    print(train_loader.dataset.data.shape)
    print(test_loader.dataset.data.shape)
    
    classes = ['plane', 'car', 'bird', 'cat', 'deer', 
               'dog', 'frog', 'horse', 'ship', 'truck']
    
    for data, target in train_loader:
        break
    print(data.shape)
    print(data[0].shape)
    plt.figure(figsize=(12,5))
    for i in range(10):
        plt.subplot(2, 5, i+1)
        plt.axis('off')
        plt.title(classes[target[i]])
        plt.imshow(data[i].permute(1, 2, 0))
    plt.show()
    return train_loader, test_loader

def show_2_in_line(loss_train, accuracy_train, loss_test, accuracy_test, epochs=1, model_name=''):
    plt.figure(figsize=(12,4))
    plt.subplot(1, 2, 1)
    plt.title(model_name + ' - Loss')
    plt.xlabel('epochs')
    plt.plot(range(epochs),loss_train, 'g',label='train')
    plt.plot(range(epochs),loss_test, 'r',label='test')
    plt.legend()
    plt.grid()
    plt.subplot(1, 2, 2)
    plt.title(model_name + ' - Accuracy')
    plt.xlabel('epochs')
    plt.plot(range(epochs),accuracy_train,'g',label='train')
    plt.plot(range(epochs),accuracy_test,'r',label='test')
    plt.legend()
    plt.grid()
    plt.show()
  
def main():

    args, kwargs, device = read_settings()
    train_loader, test_loader = load_dataset(args, kwargs)
    
# start - загрузка модели + параметры накопления

    model = FullyConnectedNN().to(device)
    print(str(model.name2))
    summary(model, input_size=(1,3072))
  
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum)


    train_last_loss_list = []
    train_accuracy_list = []
    test_average_loss_list = []
    test_accuracy_list = []
    
    start_epoch = 1
    
    dict_for_save = dict()
# end - загрузка модели + параметры накопления
    start = datetime.datetime.now()
    for epoch in range(start_epoch, args.epochs + 1):
        train_last_loss, train_accuracy = train(args, model, device, train_loader, optimizer, epoch)
        test_average_loss, test_accuracy = test(args, model, device, test_loader)
        train_last_loss_list.append(train_last_loss)
        train_accuracy_list.append(train_accuracy)
        test_average_loss_list.append(test_average_loss)
        test_accuracy_list.append(test_accuracy)

#         start - что сохраняем каждую эпоху по одной модели
        if (args.save_model):
            f = current_path + str(model.name2) + '_model_' + str(epoch).rjust(2,'0') + ".pt"
            torch.save(model,f)
            print('Save model in {}'.format(f))
        dict_for_save = dict(train_last_loss_list = train_last_loss_list,
                             train_train_accuracy_listaccuracy = train_accuracy_list,
                             test_average_loss_list = test_average_loss_list,
                             test_accuracy_list = test_accuracy_list
#                             ,может время или что еще захочу
                            )
        print(save_my_param(model, dict_for_save, after_n_epochs=epoch))
#         end - что сохраняем каждую эпоху по одной модели

    end = datetime.datetime.now()
    time_train = end-start        
    print('Model ( {} ) time - {}'.format(str(model.name2), time_train))
    
    show_2_in_line(train_last_loss_list, train_accuracy_list, test_average_loss_list, test_accuracy_list, args.epochs, str(model.name2))

# %%
main()
# Out:
# use_cuda : False
# Files already downloaded and verified
# 50000 10000 <class 'torchvision.datasets.cifar.CIFAR10'>
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# torch.Size([64, 3, 32, 32])
# torch.Size([3, 32, 32])
# FullyConnectedNN
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1              [-1, 1, 1024]       3,146,752
#               ReLU-2              [-1, 1, 1024]               0
#             Linear-3               [-1, 1, 256]         262,400
#               ReLU-4               [-1, 1, 256]               0
#             Linear-5               [-1, 1, 128]          32,896
#               ReLU-6               [-1, 1, 128]               0
#             Linear-7                [-1, 1, 10]           1,290
# ================================================================
# Total params: 3,443,338
# Trainable params: 3,443,338
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.02
# Params size (MB): 13.14
# Estimated Total Size (MB): 13.17
# ----------------------------------------------------------------
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.310406 correct: 0.01%
# Train Epoch: 1 [5120/50000 (10%)]	Loss: 2.285799 correct: 1.09%
# Train Epoch: 1 [10240/50000 (20%)]	Loss: 2.247876 correct: 2.30%
# Train Epoch: 1 [15360/50000 (31%)]	Loss: 2.200985 correct: 4.14%
# Train Epoch: 1 [20480/50000 (41%)]	Loss: 2.150177 correct: 6.14%
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 2.083520 correct: 8.28%
# Train Epoch: 1 [30720/50000 (61%)]	Loss: 2.042750 correct: 10.71%
# Train Epoch: 1 [35840/50000 (72%)]	Loss: 2.061315 correct: 13.26%
# Train Epoch: 1 [40960/50000 (82%)]	Loss: 1.917471 correct: 16.11%
# Train Epoch: 1 [46080/50000 (92%)]	Loss: 1.783224 correct: 18.73%
#
# Test set: Average loss: 1.9431, Accuracy: 2957/10000 (29.57%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_01.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_01
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_01.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_01
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.917034 correct: 0.05%
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type FullyConnectedNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Train Epoch: 2 [5120/50000 (10%)]	Loss: 1.860534 correct: 2.98%
# Train Epoch: 2 [10240/50000 (20%)]	Loss: 1.887997 correct: 6.06%
# Train Epoch: 2 [15360/50000 (31%)]	Loss: 1.840612 correct: 9.09%
# Train Epoch: 2 [20480/50000 (41%)]	Loss: 1.995313 correct: 12.35%
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.738292 correct: 15.64%
# Train Epoch: 2 [30720/50000 (61%)]	Loss: 1.803493 correct: 18.96%
# Train Epoch: 2 [35840/50000 (72%)]	Loss: 1.858152 correct: 22.35%
# Train Epoch: 2 [40960/50000 (82%)]	Loss: 1.779453 correct: 25.82%
# Train Epoch: 2 [46080/50000 (92%)]	Loss: 1.886474 correct: 29.19%
#
# Test set: Average loss: 1.8516, Accuracy: 3322/10000 (33.22%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_02.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_02
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_02.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_02
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.754879 correct: 0.04%
# Train Epoch: 3 [5120/50000 (10%)]	Loss: 1.700626 correct: 3.54%
# Train Epoch: 3 [10240/50000 (20%)]	Loss: 1.833476 correct: 7.10%
# Train Epoch: 3 [15360/50000 (31%)]	Loss: 1.756004 correct: 10.76%
# Train Epoch: 3 [20480/50000 (41%)]	Loss: 1.787248 correct: 14.46%
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.870171 correct: 18.16%
# Train Epoch: 3 [30720/50000 (61%)]	Loss: 1.756558 correct: 21.88%
# Train Epoch: 3 [35840/50000 (72%)]	Loss: 1.869904 correct: 25.68%
# Train Epoch: 3 [40960/50000 (82%)]	Loss: 1.728830 correct: 29.43%
# Train Epoch: 3 [46080/50000 (92%)]	Loss: 1.716814 correct: 33.19%
#
# Test set: Average loss: 1.7437, Accuracy: 3717/10000 (37.17%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_03.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_03
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_03.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_03
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.886759 correct: 0.04%
# Train Epoch: 4 [5120/50000 (10%)]	Loss: 1.990758 correct: 3.90%
# Train Epoch: 4 [10240/50000 (20%)]	Loss: 1.763736 correct: 7.90%
# Train Epoch: 4 [15360/50000 (31%)]	Loss: 1.616243 correct: 11.75%
# Train Epoch: 4 [20480/50000 (41%)]	Loss: 1.723999 correct: 15.72%
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.580129 correct: 19.69%
# Train Epoch: 4 [30720/50000 (61%)]	Loss: 1.654836 correct: 23.83%
# Train Epoch: 4 [35840/50000 (72%)]	Loss: 1.907927 correct: 27.86%
# Train Epoch: 4 [40960/50000 (82%)]	Loss: 1.684020 correct: 31.97%
# Train Epoch: 4 [46080/50000 (92%)]	Loss: 1.640510 correct: 36.11%
#
# Test set: Average loss: 1.6696, Accuracy: 3910/10000 (39.10%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_04.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_04
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_04.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_04
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.735543 correct: 0.05%
# Train Epoch: 5 [5120/50000 (10%)]	Loss: 1.617914 correct: 4.13%
# Train Epoch: 5 [10240/50000 (20%)]	Loss: 1.626341 correct: 8.42%
# Train Epoch: 5 [15360/50000 (31%)]	Loss: 1.587560 correct: 12.68%
# Train Epoch: 5 [20480/50000 (41%)]	Loss: 1.425278 correct: 16.93%
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.457049 correct: 21.24%
# Train Epoch: 5 [30720/50000 (61%)]	Loss: 1.663380 correct: 25.52%
# Train Epoch: 5 [35840/50000 (72%)]	Loss: 1.518635 correct: 29.83%
# Train Epoch: 5 [40960/50000 (82%)]	Loss: 1.351815 correct: 34.23%
# Train Epoch: 5 [46080/50000 (92%)]	Loss: 1.673763 correct: 38.55%
#
# Test set: Average loss: 1.6034, Accuracy: 4301/10000 (43.01%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_05.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_05
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_05.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_05
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.580923 correct: 0.06%
# Train Epoch: 6 [5120/50000 (10%)]	Loss: 1.702168 correct: 4.46%
# Train Epoch: 6 [10240/50000 (20%)]	Loss: 1.590279 correct: 8.90%
# Train Epoch: 6 [15360/50000 (31%)]	Loss: 1.567039 correct: 13.29%
# Train Epoch: 6 [20480/50000 (41%)]	Loss: 1.542890 correct: 17.74%
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.440528 correct: 22.26%
# Train Epoch: 6 [30720/50000 (61%)]	Loss: 1.411599 correct: 26.65%
# Train Epoch: 6 [35840/50000 (72%)]	Loss: 1.778115 correct: 31.06%
# Train Epoch: 6 [40960/50000 (82%)]	Loss: 1.542846 correct: 35.64%
# Train Epoch: 6 [46080/50000 (92%)]	Loss: 1.505950 correct: 40.11%
#
# Test set: Average loss: 1.5616, Accuracy: 4374/10000 (43.74%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_06.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_06
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_06.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_06
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.524195 correct: 0.05%
# Train Epoch: 7 [5120/50000 (10%)]	Loss: 1.583104 correct: 4.63%
# Train Epoch: 7 [10240/50000 (20%)]	Loss: 2.003841 correct: 9.19%
# Train Epoch: 7 [15360/50000 (31%)]	Loss: 1.616423 correct: 13.80%
# Train Epoch: 7 [20480/50000 (41%)]	Loss: 1.535826 correct: 18.39%
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.528615 correct: 22.99%
# Train Epoch: 7 [30720/50000 (61%)]	Loss: 1.549835 correct: 27.71%
# Train Epoch: 7 [35840/50000 (72%)]	Loss: 1.559093 correct: 32.40%
# Train Epoch: 7 [40960/50000 (82%)]	Loss: 1.241323 correct: 37.19%
# Train Epoch: 7 [46080/50000 (92%)]	Loss: 1.558396 correct: 41.84%
#
# Test set: Average loss: 1.6590, Accuracy: 4206/10000 (42.06%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_07.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_07
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_07.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_07
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.469176 correct: 0.05%
# Train Epoch: 8 [5120/50000 (10%)]	Loss: 1.426466 correct: 4.80%
# Train Epoch: 8 [10240/50000 (20%)]	Loss: 1.415583 correct: 9.46%
# Train Epoch: 8 [15360/50000 (31%)]	Loss: 1.494107 correct: 14.24%
# Train Epoch: 8 [20480/50000 (41%)]	Loss: 1.451283 correct: 19.07%
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.405020 correct: 23.94%
# Train Epoch: 8 [30720/50000 (61%)]	Loss: 1.327916 correct: 28.72%
# Train Epoch: 8 [35840/50000 (72%)]	Loss: 1.198584 correct: 33.65%
# Train Epoch: 8 [40960/50000 (82%)]	Loss: 1.417682 correct: 38.46%
# Train Epoch: 8 [46080/50000 (92%)]	Loss: 1.470260 correct: 43.22%
#
# Test set: Average loss: 1.5764, Accuracy: 4352/10000 (43.52%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_08.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_08
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_08.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_08
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.494727 correct: 0.06%
# Train Epoch: 9 [5120/50000 (10%)]	Loss: 1.220906 correct: 4.82%
# Train Epoch: 9 [10240/50000 (20%)]	Loss: 1.404895 correct: 9.74%
# Train Epoch: 9 [15360/50000 (31%)]	Loss: 1.386432 correct: 14.65%
# Train Epoch: 9 [20480/50000 (41%)]	Loss: 1.646299 correct: 19.55%
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.497106 correct: 24.51%
# Train Epoch: 9 [30720/50000 (61%)]	Loss: 1.345581 correct: 29.44%
# Train Epoch: 9 [35840/50000 (72%)]	Loss: 1.812512 correct: 34.31%
# Train Epoch: 9 [40960/50000 (82%)]	Loss: 1.515246 correct: 39.22%
# Train Epoch: 9 [46080/50000 (92%)]	Loss: 1.427577 correct: 44.15%
#
# Test set: Average loss: 1.6658, Accuracy: 4064/10000 (40.64%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_09.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_09
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_09.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_09
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.672022 correct: 0.05%
# Train Epoch: 10 [5120/50000 (10%)]	Loss: 1.388743 correct: 5.13%
# Train Epoch: 10 [10240/50000 (20%)]	Loss: 1.364666 correct: 10.00%
# Train Epoch: 10 [15360/50000 (31%)]	Loss: 1.582511 correct: 15.04%
# Train Epoch: 10 [20480/50000 (41%)]	Loss: 1.384504 correct: 20.00%
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.531846 correct: 25.12%
# Train Epoch: 10 [30720/50000 (61%)]	Loss: 1.653972 correct: 30.16%
# Train Epoch: 10 [35840/50000 (72%)]	Loss: 1.428593 correct: 35.29%
# Train Epoch: 10 [40960/50000 (82%)]	Loss: 1.529027 correct: 40.30%
# Train Epoch: 10 [46080/50000 (92%)]	Loss: 1.559014 correct: 45.38%
#
# Test set: Average loss: 1.4868, Accuracy: 4604/10000 (46.04%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_10.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_10
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_10.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_10
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.523339 correct: 0.06%
# Train Epoch: 11 [5120/50000 (10%)]	Loss: 1.337402 correct: 5.40%
# Train Epoch: 11 [10240/50000 (20%)]	Loss: 1.264879 correct: 10.44%
# Train Epoch: 11 [15360/50000 (31%)]	Loss: 1.333191 correct: 15.59%
# Train Epoch: 11 [20480/50000 (41%)]	Loss: 1.596862 correct: 20.81%
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 1.305346 correct: 25.96%
# Train Epoch: 11 [30720/50000 (61%)]	Loss: 1.500662 correct: 31.01%
# Train Epoch: 11 [35840/50000 (72%)]	Loss: 1.322275 correct: 36.14%
# Train Epoch: 11 [40960/50000 (82%)]	Loss: 1.432438 correct: 41.28%
# Train Epoch: 11 [46080/50000 (92%)]	Loss: 1.565168 correct: 46.29%
#
# Test set: Average loss: 1.4508, Accuracy: 4885/10000 (48.85%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_11.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_11
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_11.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_11
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.372015 correct: 0.06%
# Train Epoch: 12 [5120/50000 (10%)]	Loss: 1.422222 correct: 5.37%
# Train Epoch: 12 [10240/50000 (20%)]	Loss: 1.399756 correct: 10.48%
# Train Epoch: 12 [15360/50000 (31%)]	Loss: 1.439340 correct: 15.73%
# Train Epoch: 12 [20480/50000 (41%)]	Loss: 1.510157 correct: 20.88%
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 1.255780 correct: 26.12%
# Train Epoch: 12 [30720/50000 (61%)]	Loss: 1.467024 correct: 31.38%
# Train Epoch: 12 [35840/50000 (72%)]	Loss: 1.719310 correct: 36.63%
# Train Epoch: 12 [40960/50000 (82%)]	Loss: 1.552711 correct: 41.78%
# Train Epoch: 12 [46080/50000 (92%)]	Loss: 1.249513 correct: 47.10%
#
# Test set: Average loss: 1.5949, Accuracy: 4276/10000 (42.76%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_12.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_12
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_12.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_12
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.609848 correct: 0.04%
# Train Epoch: 13 [5120/50000 (10%)]	Loss: 1.204988 correct: 5.41%
# Train Epoch: 13 [10240/50000 (20%)]	Loss: 1.493171 correct: 10.69%
# Train Epoch: 13 [15360/50000 (31%)]	Loss: 1.285272 correct: 16.02%
# Train Epoch: 13 [20480/50000 (41%)]	Loss: 1.487891 correct: 21.31%
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 1.142333 correct: 26.76%
# Train Epoch: 13 [30720/50000 (61%)]	Loss: 1.461900 correct: 32.09%
# Train Epoch: 13 [35840/50000 (72%)]	Loss: 1.125209 correct: 37.45%
# Train Epoch: 13 [40960/50000 (82%)]	Loss: 1.240649 correct: 42.80%
# Train Epoch: 13 [46080/50000 (92%)]	Loss: 1.168952 correct: 48.09%
#
# Test set: Average loss: 1.4669, Accuracy: 4694/10000 (46.94%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_13.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_13
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_13.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_13
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.485158 correct: 0.07%
# Train Epoch: 14 [5120/50000 (10%)]	Loss: 1.328297 correct: 5.41%
# Train Epoch: 14 [10240/50000 (20%)]	Loss: 1.140606 correct: 10.84%
# Train Epoch: 14 [15360/50000 (31%)]	Loss: 1.448550 correct: 16.22%
# Train Epoch: 14 [20480/50000 (41%)]	Loss: 1.162895 correct: 21.67%
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 1.532003 correct: 27.05%
# Train Epoch: 14 [30720/50000 (61%)]	Loss: 1.238236 correct: 32.48%
# Train Epoch: 14 [35840/50000 (72%)]	Loss: 1.195800 correct: 37.92%
# Train Epoch: 14 [40960/50000 (82%)]	Loss: 1.015144 correct: 43.37%
# Train Epoch: 14 [46080/50000 (92%)]	Loss: 1.412704 correct: 48.88%
#
# Test set: Average loss: 1.3617, Accuracy: 5148/10000 (51.48%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_14.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_14
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_14.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_14
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.233700 correct: 0.08%
# Train Epoch: 15 [5120/50000 (10%)]	Loss: 1.300566 correct: 5.46%
# Train Epoch: 15 [10240/50000 (20%)]	Loss: 1.189088 correct: 11.08%
# Train Epoch: 15 [15360/50000 (31%)]	Loss: 1.303396 correct: 16.61%
# Train Epoch: 15 [20480/50000 (41%)]	Loss: 1.426288 correct: 22.10%
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 1.330758 correct: 27.59%
# Train Epoch: 15 [30720/50000 (61%)]	Loss: 1.291142 correct: 33.00%
# Train Epoch: 15 [35840/50000 (72%)]	Loss: 1.314795 correct: 38.53%
# Train Epoch: 15 [40960/50000 (82%)]	Loss: 1.433171 correct: 44.07%
# Train Epoch: 15 [46080/50000 (92%)]	Loss: 1.220850 correct: 49.59%
#
# Test set: Average loss: 1.5785, Accuracy: 4330/10000 (43.30%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_15.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_15
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_15.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_15
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.570079 correct: 0.06%
# Train Epoch: 16 [5120/50000 (10%)]	Loss: 1.431312 correct: 5.77%
# Train Epoch: 16 [10240/50000 (20%)]	Loss: 1.475793 correct: 11.24%
# Train Epoch: 16 [15360/50000 (31%)]	Loss: 1.085340 correct: 16.82%
# Train Epoch: 16 [20480/50000 (41%)]	Loss: 1.268900 correct: 22.47%
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 1.370844 correct: 28.02%
# Train Epoch: 16 [30720/50000 (61%)]	Loss: 1.161120 correct: 33.71%
# Train Epoch: 16 [35840/50000 (72%)]	Loss: 1.181504 correct: 39.24%
# Train Epoch: 16 [40960/50000 (82%)]	Loss: 1.207665 correct: 44.83%
# Train Epoch: 16 [46080/50000 (92%)]	Loss: 1.136036 correct: 50.35%
#
# Test set: Average loss: 1.4045, Accuracy: 4967/10000 (49.67%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_16.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_16
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_16.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_16
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.347250 correct: 0.07%
# Train Epoch: 17 [5120/50000 (10%)]	Loss: 1.143404 correct: 5.73%
# Train Epoch: 17 [10240/50000 (20%)]	Loss: 1.185737 correct: 11.40%
# Train Epoch: 17 [15360/50000 (31%)]	Loss: 1.285605 correct: 17.06%
# Train Epoch: 17 [20480/50000 (41%)]	Loss: 1.436903 correct: 22.78%
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 1.304152 correct: 28.40%
# Train Epoch: 17 [30720/50000 (61%)]	Loss: 1.494616 correct: 34.01%
# Train Epoch: 17 [35840/50000 (72%)]	Loss: 1.455389 correct: 39.73%
# Train Epoch: 17 [40960/50000 (82%)]	Loss: 1.150202 correct: 45.41%
# Train Epoch: 17 [46080/50000 (92%)]	Loss: 1.201652 correct: 51.08%
#
# Test set: Average loss: 1.3537, Accuracy: 5174/10000 (51.74%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_17.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_17
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_17.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_17
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.071137 correct: 0.08%
# Train Epoch: 18 [5120/50000 (10%)]	Loss: 1.357794 correct: 5.90%
# Train Epoch: 18 [10240/50000 (20%)]	Loss: 1.176201 correct: 11.61%
# Train Epoch: 18 [15360/50000 (31%)]	Loss: 1.241302 correct: 17.36%
# Train Epoch: 18 [20480/50000 (41%)]	Loss: 1.462731 correct: 23.00%
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 1.187264 correct: 28.67%
# Train Epoch: 18 [30720/50000 (61%)]	Loss: 1.130108 correct: 34.43%
# Train Epoch: 18 [35840/50000 (72%)]	Loss: 1.142351 correct: 40.19%
# Train Epoch: 18 [40960/50000 (82%)]	Loss: 1.325494 correct: 45.94%
# Train Epoch: 18 [46080/50000 (92%)]	Loss: 1.004600 correct: 51.64%
#
# Test set: Average loss: 1.4628, Accuracy: 4808/10000 (48.08%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_18.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_18
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_18.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_18
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.259937 correct: 0.06%
# Train Epoch: 19 [5120/50000 (10%)]	Loss: 1.155162 correct: 5.89%
# Train Epoch: 19 [10240/50000 (20%)]	Loss: 1.189860 correct: 11.65%
# Train Epoch: 19 [15360/50000 (31%)]	Loss: 1.174249 correct: 17.47%
# Train Epoch: 19 [20480/50000 (41%)]	Loss: 1.199988 correct: 23.29%
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 1.320424 correct: 29.16%
# Train Epoch: 19 [30720/50000 (61%)]	Loss: 0.969308 correct: 34.99%
# Train Epoch: 19 [35840/50000 (72%)]	Loss: 0.972550 correct: 40.79%
# Train Epoch: 19 [40960/50000 (82%)]	Loss: 1.307701 correct: 46.62%
# Train Epoch: 19 [46080/50000 (92%)]	Loss: 1.144383 correct: 52.41%
#
# Test set: Average loss: 1.5721, Accuracy: 4716/10000 (47.16%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_19.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_19
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_19.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_19
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.553603 correct: 0.05%
# Train Epoch: 20 [5120/50000 (10%)]	Loss: 1.073434 correct: 5.94%
# Train Epoch: 20 [10240/50000 (20%)]	Loss: 1.412840 correct: 11.83%
# Train Epoch: 20 [15360/50000 (31%)]	Loss: 1.145764 correct: 17.74%
# Train Epoch: 20 [20480/50000 (41%)]	Loss: 0.975891 correct: 23.53%
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 1.218624 correct: 29.38%
# Train Epoch: 20 [30720/50000 (61%)]	Loss: 1.224179 correct: 35.27%
# Train Epoch: 20 [35840/50000 (72%)]	Loss: 1.211047 correct: 41.09%
# Train Epoch: 20 [40960/50000 (82%)]	Loss: 0.967995 correct: 46.96%
# Train Epoch: 20 [46080/50000 (92%)]	Loss: 1.336181 correct: 52.74%
#
# Test set: Average loss: 1.5352, Accuracy: 4656/10000 (46.56%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_20.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_20
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_20.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_20
# Train Epoch: 21 [0/50000 (0%)]	Loss: 1.525217 correct: 0.06%
# Train Epoch: 21 [5120/50000 (10%)]	Loss: 1.002979 correct: 6.07%
# Train Epoch: 21 [10240/50000 (20%)]	Loss: 1.294901 correct: 12.08%
# Train Epoch: 21 [15360/50000 (31%)]	Loss: 1.322390 correct: 18.02%
# Train Epoch: 21 [20480/50000 (41%)]	Loss: 1.163229 correct: 23.86%
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 1.023400 correct: 29.69%
# Train Epoch: 21 [30720/50000 (61%)]	Loss: 1.132160 correct: 35.68%
# Train Epoch: 21 [35840/50000 (72%)]	Loss: 1.464437 correct: 41.72%
# Train Epoch: 21 [40960/50000 (82%)]	Loss: 1.141263 correct: 47.67%
# Train Epoch: 21 [46080/50000 (92%)]	Loss: 1.056397 correct: 53.68%
#
# Test set: Average loss: 1.4107, Accuracy: 4990/10000 (49.90%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_21.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_21
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_21.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_21
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.114805 correct: 0.07%
# Train Epoch: 22 [5120/50000 (10%)]	Loss: 1.141228 correct: 6.19%
# Train Epoch: 22 [10240/50000 (20%)]	Loss: 1.013500 correct: 12.15%
# Train Epoch: 22 [15360/50000 (31%)]	Loss: 1.235751 correct: 18.19%
# Train Epoch: 22 [20480/50000 (41%)]	Loss: 1.004808 correct: 24.20%
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 1.193426 correct: 30.19%
# Train Epoch: 22 [30720/50000 (61%)]	Loss: 1.192413 correct: 36.17%
# Train Epoch: 22 [35840/50000 (72%)]	Loss: 1.079307 correct: 42.22%
# Train Epoch: 22 [40960/50000 (82%)]	Loss: 1.437843 correct: 48.30%
# Train Epoch: 22 [46080/50000 (92%)]	Loss: 1.308170 correct: 54.31%
#
# Test set: Average loss: 1.3724, Accuracy: 5097/10000 (50.97%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_22.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_22
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_22.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_22
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.988749 correct: 0.08%
# Train Epoch: 23 [5120/50000 (10%)]	Loss: 1.116794 correct: 6.11%
# Train Epoch: 23 [10240/50000 (20%)]	Loss: 1.024579 correct: 12.07%
# Train Epoch: 23 [15360/50000 (31%)]	Loss: 1.005038 correct: 18.27%
# Train Epoch: 23 [20480/50000 (41%)]	Loss: 1.137802 correct: 24.42%
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 1.490607 correct: 30.53%
# Train Epoch: 23 [30720/50000 (61%)]	Loss: 1.337325 correct: 36.64%
# Train Epoch: 23 [35840/50000 (72%)]	Loss: 1.385004 correct: 42.78%
# Train Epoch: 23 [40960/50000 (82%)]	Loss: 1.219476 correct: 48.94%
# Train Epoch: 23 [46080/50000 (92%)]	Loss: 1.192473 correct: 54.98%
#
# Test set: Average loss: 1.5491, Accuracy: 4610/10000 (46.10%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_23.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_23
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_23.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_23
# Train Epoch: 24 [0/50000 (0%)]	Loss: 1.221543 correct: 0.08%
# Train Epoch: 24 [5120/50000 (10%)]	Loss: 1.199477 correct: 6.27%
# Train Epoch: 24 [10240/50000 (20%)]	Loss: 1.365484 correct: 12.44%
# Train Epoch: 24 [15360/50000 (31%)]	Loss: 0.945919 correct: 18.68%
# Train Epoch: 24 [20480/50000 (41%)]	Loss: 1.345191 correct: 24.94%
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.935916 correct: 31.05%
# Train Epoch: 24 [30720/50000 (61%)]	Loss: 0.931767 correct: 37.03%
# Train Epoch: 24 [35840/50000 (72%)]	Loss: 1.021169 correct: 43.27%
# Train Epoch: 24 [40960/50000 (82%)]	Loss: 1.111903 correct: 49.40%
# Train Epoch: 24 [46080/50000 (92%)]	Loss: 1.271747 correct: 55.50%
#
# Test set: Average loss: 1.4469, Accuracy: 5021/10000 (50.21%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_24.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_24
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_24.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_24
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.065826 correct: 0.08%
# Train Epoch: 25 [5120/50000 (10%)]	Loss: 1.177681 correct: 6.34%
# Train Epoch: 25 [10240/50000 (20%)]	Loss: 1.021671 correct: 12.62%
# Train Epoch: 25 [15360/50000 (31%)]	Loss: 1.091000 correct: 18.91%
# Train Epoch: 25 [20480/50000 (41%)]	Loss: 1.355299 correct: 25.11%
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 1.062122 correct: 31.28%
# Train Epoch: 25 [30720/50000 (61%)]	Loss: 1.062363 correct: 37.62%
# Train Epoch: 25 [35840/50000 (72%)]	Loss: 1.417694 correct: 43.73%
# Train Epoch: 25 [40960/50000 (82%)]	Loss: 1.149583 correct: 49.89%
# Train Epoch: 25 [46080/50000 (92%)]	Loss: 1.071844 correct: 56.05%
#
# Test set: Average loss: 1.7571, Accuracy: 4281/10000 (42.81%)
#
# Save model in /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_model_25.pt
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/
# FullyConnectedNN_param_25
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_25.json
# /content/drive/My Drive/My coding/Hillel Scool/Занятие 10 - Домашка 8/FullyConnectedNN_param_25
# Model ( FullyConnectedNN ) time - 0:15:29.531132
